# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from scipy.stats import ttest_ind
import statsmodels.api as sm

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('train.csv').set_index('Id')

# %%
#Conociendo el dataset
df.shape
# Out:
# (1460, 80)

# %%
#Conociendo el dataset
df.head(1)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
#
# [1 rows x 80 columns]

# %%
#Buscando columnas con muchos nulos
null_cols = df.isnull().sum()
null_cols[null_cols > 0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
#Borrando columnas con muchos nulos
drop_cols = list(null_cols[null_cols > 689].index)
df = df.drop(drop_cols, axis=1)

# %%
#Nuevo shape despues de borrar
df.shape
# Out:
# (1460, 75)

# %%
df.head(1)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# Id
# 1           60       RL         65.0     8450   Pave      Reg         Lvl
#
#    Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# Id                                ...
# 1     AllPub    Inside       Gtl  ...             0         0           0
#
#    PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# Id
# 1         0       0       2    2008        WD         Normal    208500
#
# [1 rows x 75 columns]

# %%
#Conociendo las columnas numericas
df.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000  ...
# 25%    1954.000000   1967.000000     0.000000     0.000000     0.000000  ...
# 50%    1973.000000   1994.000000     0.000000   383.500000     0.000000  ...
# 75%    2000.000000   2004.000000   166.000000   712.250000     0.000000  ...
# max    2010.000000   2010.000000  1600.000000  5644.000000  1474.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 37 columns]

# %%
#Conociendo las columnas numericas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
#  17  YearBuilt      1460 non-null   int64
#  18  YearRemodAdd   1460 non-null   int64
#  19  RoofStyle      1460 non-null   object
#  20  RoofMatl       1460 non-null   object
#  21  Exterior1st    1460 non-null   object
#  22  Exterior2nd    1460 non-null   object
#  23  MasVnrType     1452 non-null   object
#  24  MasVnrArea     1452 non-null   float64
#  25  ExterQual      1460 non-null   object
#  26  ExterCond      1460 non-null   object
#  27  Foundation     1460 non-null   object
#  28  BsmtQual       1423 non-null   object
#  29  BsmtCond       1423 non-null   object
#  30  BsmtExposure   1422 non-null   object
#  31  BsmtFinType1   1423 non-null   object
#  32  BsmtFinSF1     1460 non-null   int64
#  33  BsmtFinType2   1422 non-null   object
#  34  BsmtFinSF2     1460 non-null   int64
#  35  BsmtUnfSF      1460 non-null   int64
#  36  TotalBsmtSF    1460 non-null   int64
#  37  Heating        1460 non-null   object
#  38  HeatingQC      1460 non-null   object
#  39  CentralAir     1460 non-null   object
#  40  Electrical     1459 non-null   object
#  41  1stFlrSF       1460 non-null   int64
#  42  2ndFlrSF       1460 non-null   int64
#  43  LowQualFinSF   1460 non-null   int64
#  44  GrLivArea      1460 non-null   int64
#  45  BsmtFullBath   1460 non-null   int64
#  46  BsmtHalfBath   1460 non-null   int64
#  47  FullBath       1460 non-null   int64
#  48  HalfBath       1460 non-null   int64
#  49  BedroomAbvGr   1460 non-null   int64
#  50  KitchenAbvGr   1460 non-null   int64
#  51  KitchenQual    1460 non-null   object
#  52  TotRmsAbvGrd   1460 non-null   int64
#  53  Functional     1460 non-null   object
#  54  Fireplaces     1460 non-null   int64
#  55  GarageType     1379 non-null   object
#  56  GarageYrBlt    1379 non-null   float64
#  57  GarageFinish   1379 non-null   object
#  58  GarageCars     1460 non-null   int64
#  59  GarageArea     1460 non-null   int64
#  60  GarageQual     1379 non-null   object
#  61  GarageCond     1379 non-null   object
#  62  PavedDrive     1460 non-null   object
#  63  WoodDeckSF     1460 non-null   int64
#  64  OpenPorchSF    1460 non-null   int64
#  65  EnclosedPorch  1460 non-null   int64
#  66  3SsnPorch      1460 non-null   int64
#  67  ScreenPorch    1460 non-null   int64
#  68  PoolArea       1460 non-null   int64
#  69  MiscVal        1460 non-null   int64
#  70  MoSold         1460 non-null   int64
#  71  YrSold         1460 non-null   int64
#  72  SaleType       1460 non-null   object
#  73  SaleCondition  1460 non-null   object
#  74  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(34), object(38)
# memory usage: 866.9+ KB

# %%
#Creando lista con el nombre de las columnas
col_names = list(df.columns)

# %%
col_names
# Out:
# ['MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageCars',
#  'GarageArea',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SaleType',
#  'SaleCondition',
#  'SalePrice']

# %%
#identificando columnas de baja varianza
low_variance = []
 
for col in df._get_numeric_data():
    minimum = min(df[col])
    ninety_perc = np.percentile(df[col], 90)
    if ninety_perc == minimum:
        low_variance.append(col)
 
print(low_variance)
# Out:
# ['LowQualFinSF', 'BsmtHalfBath', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal']

# %%
#borrando columnas de baja varianza
df = df.drop(low_variance, axis=1)

# %%
#nuevo shape
df.shape
# Out:
# (1460, 69)

# %%
#Buscando outliers
stats = df.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats
# Out:
#                 count           mean           std      min        25%  \
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# TotalBsmtSF    1460.0    1057.429452    438.705324      0.0     795.75
# 1stFlrSF       1460.0    1162.626712    386.587738    334.0     882.00
# 2ndFlrSF       1460.0     346.992466    436.528436      0.0       0.00
# GrLivArea      1460.0    1515.463699    525.480383    334.0    1129.50
# BsmtFullBath   1460.0       0.425342      0.518911      0.0       0.00
# FullBath       1460.0       1.565068      0.550916      0.0       1.00
# HalfBath       1460.0       0.382877      0.502885      0.0       0.00
# BedroomAbvGr   1460.0       2.866438      0.815778      0.0       2.00
# KitchenAbvGr   1460.0       1.046575      0.220338      0.0       1.00
# TotRmsAbvGrd   1460.0       6.517808      1.625393      2.0       5.00
# Fireplaces     1460.0       0.613014      0.644666      0.0       0.00
# GarageYrBlt    1379.0    1978.506164     24.689725   1900.0    1961.00
# GarageCars     1460.0       1.767123      0.747315      0.0       1.00
# GarageArea     1460.0     472.980137    213.804841      0.0     334.50
# WoodDeckSF     1460.0      94.244521    125.338794      0.0       0.00
# OpenPorchSF    1460.0      46.660274     66.256028      0.0       0.00
# EnclosedPorch  1460.0      21.954110     61.119149      0.0       0.00
# MoSold         1460.0       6.321918      2.703626      1.0       5.00
# YrSold         1460.0    2007.815753      1.328095   2006.0    2007.00
# SalePrice      1460.0  180921.195890  79442.502883  34900.0  129975.00
#
#                     50%        75%       max       IQR
# MSSubClass         50.0      70.00     190.0     50.00
# LotFrontage        69.0      80.00     313.0     21.00
# LotArea          9478.5   11601.50  215245.0   4048.00
# OverallQual         6.0       7.00      10.0      2.00
# OverallCond         5.0       6.00       9.0      1.00
# YearBuilt        1973.0    2000.00    2010.0     46.00
# YearRemodAdd     1994.0    2004.00    2010.0     37.00
# MasVnrArea          0.0     166.00    1600.0    166.00
# BsmtFinSF1        383.5     712.25    5644.0    712.25
# BsmtFinSF2          0.0       0.00    1474.0      0.00
# BsmtUnfSF         477.5     808.00    2336.0    585.00
# TotalBsmtSF       991.5    1298.25    6110.0    502.50
# 1stFlrSF         1087.0    1391.25    4692.0    509.25
# 2ndFlrSF            0.0     728.00    2065.0    728.00
# GrLivArea        1464.0    1776.75    5642.0    647.25
# BsmtFullBath        0.0       1.00       3.0      1.00
# FullBath            2.0       2.00       3.0      1.00
# HalfBath            0.0       1.00       2.0      1.00
# BedroomAbvGr        3.0       3.00       8.0      1.00
# KitchenAbvGr        1.0       1.00       3.0      0.00
# TotRmsAbvGrd        6.0       7.00      14.0      2.00
# Fireplaces          1.0       1.00       3.0      1.00
# GarageYrBlt      1980.0    2002.00    2010.0     41.00
# GarageCars          2.0       2.00       4.0      1.00
# GarageArea        480.0     576.00    1418.0    241.50
# WoodDeckSF          0.0     168.00     857.0    168.00
# OpenPorchSF        25.0      68.00     547.0     68.00
# EnclosedPorch       0.0       0.00     552.0      0.00
# MoSold              6.0       8.00      12.0      3.00
# YrSold           2008.0    2009.00    2010.0      2.00
# SalePrice      163000.0  214000.00  755000.0  84025.00

# %%
#Creando DF con los outliers
outliers = pd.DataFrame(columns=df.columns)
 
for col in stats.index:
    iqr = stats.at[col,'IQR']
    cutoff = iqr * 1.5
    lower = stats.at[col,'25%'] - cutoff
    upper = stats.at[col,'75%'] + cutoff
    results = df[(df[col] < lower) | 
                   (df[col] > upper)].copy()
    results['Outlier'] = col
    outliers = outliers.append(results)

# %%
#son demasiados, no los voy a borrar
outliers.shape
# Out:
# (1350, 70)

# %%
df.dtypes
# Out:
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 69, dtype: object

# %%
#Llenando valores nan con 0 en la columna de LotFrontage, asumo que son depas y tienen 0 patio frontal
df['LotFrontage'] = df['LotFrontage'].fillna(0)

# %%
#shape final
df.shape
# Out:
# (1460, 69)

# %%
#Viendo correlaciones entre las columnas numericas, sobre todo contra el valor de venta (SalePrice)
df.corr()
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.215023 -0.139781     0.032628    -0.059316
# LotFrontage     -0.215023     1.000000  0.100739     0.176561    -0.053457
# LotArea         -0.139781     0.100739  1.000000     0.105806    -0.005636
# OverallQual      0.032628     0.176561  0.105806     1.000000    -0.091932
# OverallCond     -0.059316    -0.053457 -0.005636    -0.091932     1.000000
# YearBuilt        0.027850     0.036853  0.014228     0.572323    -0.375983
# YearRemodAdd     0.040581     0.078686  0.013788     0.550684     0.073741
# MasVnrArea       0.022936     0.105255  0.104160     0.411876    -0.128101
# BsmtFinSF1      -0.069836     0.076670  0.214103     0.239666    -0.046231
# BsmtFinSF2      -0.065649    -0.009312  0.111170    -0.059119     0.040229
# BsmtUnfSF       -0.140759     0.160829 -0.002618     0.308159    -0.136841
# TotalBsmtSF     -0.238518     0.238274  0.260833     0.537808    -0.171098
# 1stFlrSF        -0.251758     0.245181  0.299475     0.476224    -0.144203
# 2ndFlrSF         0.307886     0.042549  0.050986     0.295493     0.028942
# GrLivArea        0.074853     0.220347  0.263116     0.593007    -0.079686
# BsmtFullBath     0.003491     0.010514  0.158155     0.111098    -0.054942
# FullBath         0.131608     0.120548  0.126031     0.550600    -0.194149
# HalfBath         0.177354    -0.012952  0.014259     0.273458    -0.060769
# BedroomAbvGr    -0.023438     0.144494  0.119690     0.101676     0.012980
# KitchenAbvGr     0.281721     0.034425 -0.017784    -0.183882    -0.087001
# TotRmsAbvGrd     0.040380     0.221396  0.190015     0.427452    -0.057583
# Fireplaces      -0.045569     0.044018  0.271364     0.396765    -0.023820
# GarageYrBlt      0.085072     0.044045 -0.024947     0.547766    -0.324297
# GarageCars      -0.040110     0.165229  0.154871     0.600671    -0.185758
# GarageArea      -0.098672     0.201473  0.180403     0.562022    -0.151521
# WoodDeckSF      -0.012579    -0.016780  0.171698     0.238923    -0.003334
# OpenPorchSF     -0.006100     0.069605  0.084774     0.308819    -0.032589
# EnclosedPorch   -0.012037     0.027366 -0.018340    -0.113937     0.070356
# MoSold          -0.013585     0.018942  0.001205     0.070815    -0.003511
# YrSold          -0.021407    -0.012094 -0.014261    -0.027347     0.043950
# SalePrice       -0.084284     0.209624  0.263843     0.790982    -0.077856
#
#                YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# MSSubClass      0.027850      0.040581    0.022936   -0.069836   -0.065649
# LotFrontage     0.036853      0.078686    0.105255    0.076670   -0.009312
# LotArea         0.014228      0.013788    0.104160    0.214103    0.111170
# OverallQual     0.572323      0.550684    0.411876    0.239666   -0.059119
# OverallCond    -0.375983      0.073741   -0.128101   -0.046231    0.040229
# YearBuilt       1.000000      0.592855    0.315707    0.249503   -0.049107
# YearRemodAdd    0.592855      1.000000    0.179618    0.128451   -0.067759
# MasVnrArea      0.315707      0.179618    1.000000    0.264736   -0.072319
# BsmtFinSF1      0.249503      0.128451    0.264736    1.000000   -0.050117
# BsmtFinSF2     -0.049107     -0.067759   -0.072319   -0.050117    1.000000
# BsmtUnfSF       0.149040      0.181133    0.114442   -0.495251   -0.209294
# TotalBsmtSF     0.391452      0.291066    0.363936    0.522396    0.104810
# 1stFlrSF        0.281986      0.240379    0.344501    0.445863    0.097117
# 2ndFlrSF        0.010308      0.140024    0.174561   -0.137079   -0.099260
# GrLivArea       0.199010      0.287389    0.390857    0.208171   -0.009640
# BsmtFullBath    0.187599      0.119470    0.085310    0.649212    0.158678
# FullBath        0.468271      0.439046    0.276833    0.058543   -0.076444
# HalfBath        0.242656      0.183331    0.201444    0.004262   -0.032148
# BedroomAbvGr   -0.070651     -0.040581    0.102821   -0.107355   -0.015728
# KitchenAbvGr   -0.174800     -0.149598   -0.037610   -0.081007   -0.040751
# TotRmsAbvGrd    0.095589      0.191740    0.280682    0.044316   -0.035227
# Fireplaces      0.147716      0.112581    0.249070    0.260011    0.046921
# GarageYrBlt     0.825667      0.642277    0.252691    0.153484   -0.088011
# GarageCars      0.537850      0.420622    0.364204    0.224054   -0.038264
# GarageArea      0.478954      0.371600    0.373066    0.296970   -0.018227
# WoodDeckSF      0.224880      0.205726    0.159718    0.204306    0.067898
# OpenPorchSF     0.188686      0.226298    0.125703    0.111761    0.003093
# EnclosedPorch  -0.387268     -0.193919   -0.110204   -0.102303    0.036543
# MoSold          0.012398      0.021490   -0.005965   -0.015727   -0.015211
# YrSold         -0.013618      0.035743   -0.008201    0.014359    0.031706
# SalePrice       0.522897      0.507101    0.477493    0.386420   -0.011378
#
#                ...  Fireplaces  GarageYrBlt  GarageCars  GarageArea  \
# MSSubClass     ...   -0.045569     0.085072   -0.040110   -0.098672
# LotFrontage    ...    0.044018     0.044045    0.165229    0.201473
# LotArea        ...    0.271364    -0.024947    0.154871    0.180403
# OverallQual    ...    0.396765     0.547766    0.600671    0.562022
# OverallCond    ...   -0.023820    -0.324297   -0.185758   -0.151521
# YearBuilt      ...    0.147716     0.825667    0.537850    0.478954
# YearRemodAdd   ...    0.112581     0.642277    0.420622    0.371600
# MasVnrArea     ...    0.249070     0.252691    0.364204    0.373066
# BsmtFinSF1     ...    0.260011     0.153484    0.224054    0.296970
# BsmtFinSF2     ...    0.046921    -0.088011   -0.038264   -0.018227
# BsmtUnfSF      ...    0.051575     0.190708    0.214175    0.183303
# TotalBsmtSF    ...    0.339519     0.322445    0.434585    0.486665
# 1stFlrSF       ...    0.410531     0.233449    0.439317    0.489782
# 2ndFlrSF       ...    0.194561     0.070832    0.183926    0.138347
# GrLivArea      ...    0.461679     0.231197    0.467247    0.468997
# BsmtFullBath   ...    0.137928     0.124553    0.131881    0.179189
# FullBath       ...    0.243671     0.484557    0.469672    0.405656
# HalfBath       ...    0.203649     0.196785    0.219178    0.163549
# BedroomAbvGr   ...    0.107570    -0.064518    0.086106    0.065253
# KitchenAbvGr   ...   -0.123936    -0.124411   -0.050634   -0.064433
# TotRmsAbvGrd   ...    0.326114     0.148112    0.362289    0.337822
# Fireplaces     ...    1.000000     0.046822    0.300789    0.269141
# GarageYrBlt    ...    0.046822     1.000000    0.588920    0.564567
# GarageCars     ...    0.300789     0.588920    1.000000    0.882475
# GarageArea     ...    0.269141     0.564567    0.882475    1.000000
# WoodDeckSF     ...    0.200019     0.224577    0.226342    0.224666
# OpenPorchSF    ...    0.169405     0.228425    0.213569    0.241435
# EnclosedPorch  ...   -0.024822    -0.297003   -0.151434   -0.121777
# MoSold         ...    0.046357     0.005337    0.040522    0.027974
# YrSold         ...   -0.024096    -0.001014   -0.039117   -0.027378
# SalePrice      ...    0.466929     0.486362    0.640409    0.623431
#
#                WoodDeckSF  OpenPorchSF  EnclosedPorch    MoSold    YrSold  \
# MSSubClass      -0.012579    -0.006100      -0.012037 -0.013585 -0.021407
# LotFrontage     -0.016780     0.069605       0.027366  0.018942 -0.012094
# LotArea          0.171698     0.084774      -0.018340  0.001205 -0.014261
# OverallQual      0.238923     0.308819      -0.113937  0.070815 -0.027347
# OverallCond     -0.003334    -0.032589       0.070356 -0.003511  0.043950
# YearBuilt        0.224880     0.188686      -0.387268  0.012398 -0.013618
# YearRemodAdd     0.205726     0.226298      -0.193919  0.021490  0.035743
# MasVnrArea       0.159718     0.125703      -0.110204 -0.005965 -0.008201
# BsmtFinSF1       0.204306     0.111761      -0.102303 -0.015727  0.014359
# BsmtFinSF2       0.067898     0.003093       0.036543 -0.015211  0.031706
# BsmtUnfSF       -0.005316     0.129005      -0.002538  0.034888 -0.041258
# TotalBsmtSF      0.232019     0.247264      -0.095478  0.013196 -0.014969
# 1stFlrSF         0.235459     0.211671      -0.065292  0.031372 -0.013604
# 2ndFlrSF         0.092165     0.208026       0.061989  0.035164 -0.028700
# GrLivArea        0.247433     0.330224       0.009113  0.050240 -0.036526
# BsmtFullBath     0.175315     0.067341      -0.049911 -0.025361  0.067049
# FullBath         0.187703     0.259977      -0.115093  0.055872 -0.019669
# HalfBath         0.108080     0.199740      -0.095317 -0.009050 -0.010269
# BedroomAbvGr     0.046854     0.093810       0.041570  0.046544 -0.036014
# KitchenAbvGr    -0.090130    -0.070091       0.037312  0.026589  0.031687
# TotRmsAbvGrd     0.165984     0.234192       0.004151  0.036907 -0.034516
# Fireplaces       0.200019     0.169405      -0.024822  0.046357 -0.024096
# GarageYrBlt      0.224577     0.228425      -0.297003  0.005337 -0.001014
# GarageCars       0.226342     0.213569      -0.151434  0.040522 -0.039117
# GarageArea       0.224666     0.241435      -0.121777  0.027974 -0.027378
# WoodDeckSF       1.000000     0.058661      -0.125989  0.021011  0.022270
# OpenPorchSF      0.058661     1.000000      -0.093079  0.071255 -0.057619
# EnclosedPorch   -0.125989    -0.093079       1.000000 -0.028887 -0.009916
# MoSold           0.021011     0.071255      -0.028887  1.000000 -0.145721
# YrSold           0.022270    -0.057619      -0.009916 -0.145721  1.000000
# SalePrice        0.324413     0.315856      -0.128578  0.046432 -0.028923
#
#                SalePrice
# MSSubClass     -0.084284
# LotFrontage     0.209624
# LotArea         0.263843
# OverallQual     0.790982
# OverallCond    -0.077856
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# MasVnrArea      0.477493
# BsmtFinSF1      0.386420
# BsmtFinSF2     -0.011378
# BsmtUnfSF       0.214479
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# 2ndFlrSF        0.319334
# GrLivArea       0.708624
# BsmtFullBath    0.227122
# FullBath        0.560664
# HalfBath        0.284108
# BedroomAbvGr    0.168213
# KitchenAbvGr   -0.135907
# TotRmsAbvGrd    0.533723
# Fireplaces      0.466929
# GarageYrBlt     0.486362
# GarageCars      0.640409
# GarageArea      0.623431
# WoodDeckSF      0.324413
# OpenPorchSF     0.315856
# EnclosedPorch  -0.128578
# MoSold          0.046432
# YrSold         -0.028923
# SalePrice       1.000000
#
# [31 rows x 31 columns]

# %%
#identificando columnas numericas y creando un df con ellas
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

newdf = df.select_dtypes(include=numerics)

# %%
newdf.shape
# Out:
# (1460, 31)

# %%
newdf.head()
# Out:
#     MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1           60         65.0     8450            7            5       2003
# 2           20         80.0     9600            6            8       1976
# 3           60         68.0    11250            7            5       2001
# 4           70         60.0     9550            7            5       1915
# 5           60         84.0    14260            8            5       2000
#
#     YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  Fireplaces  \
# Id                                                    ...
# 1           2003       196.0         706           0  ...           0
# 2           1976         0.0         978           0  ...           1
# 3           2002       162.0         486           0  ...           1
# 4           1970         0.0         216           0  ...           1
# 5           2000       350.0         655           0  ...           1
#
#     GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  \
# Id
# 1        2003.0           2         548           0           61
# 2        1976.0           2         460         298            0
# 3        2001.0           2         608           0           42
# 4        1998.0           3         642           0           35
# 5        2000.0           3         836         192           84
#
#     EnclosedPorch  MoSold  YrSold  SalePrice
# Id
# 1               0       2    2008     208500
# 2               0       5    2007     181500
# 3               0       9    2008     223500
# 4             272       2    2006     140000
# 5               0      12    2008     250000
#
# [5 rows x 31 columns]

# %%
newdf.dtypes
# Out:
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# GrLivArea          int64
# BsmtFullBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# MoSold             int64
# YrSold             int64
# SalePrice          int64
# dtype: object

# %%
#Empiezo a visualizar los datos con matplotlib
newdf.SalePrice.hist();

# %%
#Clara relación entre el precio de venta y la calidad
plt.scatter(df.SalePrice,df.OverallQual);

# %%
#también hay relación entre el precio de venta y la condición
plt.scatter(df.SalePrice,df.OverallCond);

# %%
#y también entre el precio de venta y el año de construcción
plt.scatter(df.SalePrice,df.YearBuilt);

# %%
"""Por lo visto en las correlaciones y gráficos de dispersión 
   me quedo con estas columnas como las más importantes para el precio de ventas"""

df_2 = df[['LotArea', 'Utilities', 'OverallQual', 
           'OverallCond', 'YearRemodAdd', 'YearBuilt', 'YrSold', 'SalePrice', 'MasVnrArea', ]].copy()

# %%
df_2.head(1)
# Out:
#     LotArea Utilities  OverallQual  OverallCond  YearRemodAdd  YearBuilt  \
# Id
# 1      8450    AllPub            7            5          2003       2003
#
#     YrSold  SalePrice  MasVnrArea
# Id
# 1     2008     208500       196.0

# %%
#De esas columnas tomo las continuas para hacer una prueba de correlación Pearson
df_pearson = df[['LotArea', 'YearBuilt', 'YrSold', 'YearRemodAdd', 'MasVnrArea', 'SalePrice']].copy()

# %%
corr = df_pearson.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow0_col0,#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow1_col1,#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow2_col2,#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow3_col3,#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow4_col4,#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow5_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow0_col1,#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow1_col0,#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow3_col0{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow0_col2,#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow1_col2{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow0_col3,#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow2_col0,#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow2_col1,#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow2_col4,#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow2_col5,#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow5_col2{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow0_col4{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow0_col5{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow1_col3{
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow1_col4{
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow1_col5{
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow2_col3,#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow4_col2{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow3_col1{
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow3_col2{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow3_col4{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow3_col5{
#             background-color:  #e2dad5;
#             color:  #000000;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow4_col0{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow4_col1{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow4_col3{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow4_col5{
#             background-color:  #dadce0;
#             color:  #000000;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow5_col0{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow5_col1{
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow5_col3{
#             background-color:  #dddcdc;
#             color:  #000000;
#         }#T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow5_col4{
#             background-color:  #d8dce2;
#             color:  #000000;
#         }</style><table id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bb" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >LotArea</th>        <th class="col_heading level0 col1" >YearBuilt</th>        <th class="col_heading level0 col2" >YrSold</th>        <th class="col_heading level0 col3" >YearRemodAdd</th>        <th class="col_heading level0 col4" >MasVnrArea</th>        <th class="col_heading level0 col5" >SalePrice</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bblevel0_row0" class="row_heading level0 row0" >LotArea</th>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow0_col1" class="data row0 col1" >0.014228</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow0_col2" class="data row0 col2" >-0.014261</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow0_col3" class="data row0 col3" >0.013788</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow0_col4" class="data row0 col4" >0.104160</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow0_col5" class="data row0 col5" >0.263843</td>
#             </tr>
#             <tr>
#                         <th id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bblevel0_row1" class="row_heading level0 row1" >YearBuilt</th>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow1_col0" class="data row1 col0" >0.014228</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow1_col2" class="data row1 col2" >-0.013618</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow1_col3" class="data row1 col3" >0.592855</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow1_col4" class="data row1 col4" >0.315707</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow1_col5" class="data row1 col5" >0.522897</td>
#             </tr>
#             <tr>
#                         <th id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bblevel0_row2" class="row_heading level0 row2" >YrSold</th>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow2_col0" class="data row2 col0" >-0.014261</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow2_col1" class="data row2 col1" >-0.013618</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow2_col3" class="data row2 col3" >0.035743</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow2_col4" class="data row2 col4" >-0.008201</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow2_col5" class="data row2 col5" >-0.028923</td>
#             </tr>
#             <tr>
#                         <th id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bblevel0_row3" class="row_heading level0 row3" >YearRemodAdd</th>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow3_col0" class="data row3 col0" >0.013788</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow3_col1" class="data row3 col1" >0.592855</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow3_col2" class="data row3 col2" >0.035743</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow3_col4" class="data row3 col4" >0.179618</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow3_col5" class="data row3 col5" >0.507101</td>
#             </tr>
#             <tr>
#                         <th id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bblevel0_row4" class="row_heading level0 row4" >MasVnrArea</th>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow4_col0" class="data row4 col0" >0.104160</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238dcc5bbrow4_col1" class="data row4 col1" >0.315707</td>
#                         <td id="T_4fa179a2_e27d_11eb_ba0f_004238d

# %%
#Con las otras hago una prueba de correlación Spearman
df_spearman = df[['OverallQual', 'OverallCond', 'SalePrice']].copy()
corr_spearman = df_spearman.corr('spearman')
corr_spearman.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_4fa79834_e27d_11eb_becb_004238dcc5bbrow0_col0,#T_4fa79834_e27d_11eb_becb_004238dcc5bbrow1_col1,#T_4fa79834_e27d_11eb_becb_004238dcc5bbrow2_col2{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_4fa79834_e27d_11eb_becb_004238dcc5bbrow0_col1,#T_4fa79834_e27d_11eb_becb_004238dcc5bbrow1_col0,#T_4fa79834_e27d_11eb_becb_004238dcc5bbrow1_col2{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_4fa79834_e27d_11eb_becb_004238dcc5bbrow0_col2{
#             background-color:  #e8765c;
#             color:  #000000;
#         }#T_4fa79834_e27d_11eb_becb_004238dcc5bbrow2_col0{
#             background-color:  #e67259;
#             color:  #000000;
#         }#T_4fa79834_e27d_11eb_becb_004238dcc5bbrow2_col1{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }</style><table id="T_4fa79834_e27d_11eb_becb_004238dcc5bb" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >OverallQual</th>        <th class="col_heading level0 col1" >OverallCond</th>        <th class="col_heading level0 col2" >SalePrice</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4fa79834_e27d_11eb_becb_004238dcc5bblevel0_row0" class="row_heading level0 row0" >OverallQual</th>
#                         <td id="T_4fa79834_e27d_11eb_becb_004238dcc5bbrow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_4fa79834_e27d_11eb_becb_004238dcc5bbrow0_col1" class="data row0 col1" >-0.177521</td>
#                         <td id="T_4fa79834_e27d_11eb_becb_004238dcc5bbrow0_col2" class="data row0 col2" >0.809829</td>
#             </tr>
#             <tr>
#                         <th id="T_4fa79834_e27d_11eb_becb_004238dcc5bblevel0_row1" class="row_heading level0 row1" >OverallCond</th>
#                         <td id="T_4fa79834_e27d_11eb_becb_004238dcc5bbrow1_col0" class="data row1 col0" >-0.177521</td>
#                         <td id="T_4fa79834_e27d_11eb_becb_004238dcc5bbrow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_4fa79834_e27d_11eb_becb_004238dcc5bbrow1_col2" class="data row1 col2" >-0.129325</td>
#             </tr>
#             <tr>
#                         <th id="T_4fa79834_e27d_11eb_becb_004238dcc5bblevel0_row2" class="row_heading level0 row2" >SalePrice</th>
#                         <td id="T_4fa79834_e27d_11eb_becb_004238dcc5bbrow2_col0" class="data row2 col0" >0.809829</td>
#                         <td id="T_4fa79834_e27d_11eb_becb_004238dcc5bbrow2_col1" class="data row2 col1" >-0.129325</td>
#                         <td id="T_4fa79834_e27d_11eb_becb_004238dcc5bbrow2_col2" class="data row2 col2" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
#Con la función que crea el heatmap que nos mostró Julian
def correlation_plot(corr, title="Heatmap"):
  mask = np.zeros_like(df_pearson.corr(), dtype=np.bool)
  # Nos regresa la matriz diagonal superior
  mask[np.triu_indices_from(mask)] = True
  plt.subplots(figsize=(10,8))
  cmap = sns.diverging_palette(6,255, as_cmap=True)
  chart = sns.heatmap(corr, mask = mask, cmap = cmap, center = 0, linewidth = .5, annot = True)
  plt.title(title, fontsize=15)
  return chart

# %%
correlation_plot(df_pearson.corr());

# %%
#Idem
def correlation_plot_2(corr, title="Heatmap"):
  mask = np.zeros_like(df_spearman.corr(), dtype=np.bool)
  # Nos regresa la matriz diagonal superior
  mask[np.triu_indices_from(mask)] = True
  plt.subplots(figsize=(10,8))
  cmap = sns.diverging_palette(6,255, as_cmap=True)
  chart = sns.heatmap(corr, mask = mask, cmap = cmap, center = 0, linewidth = .5, annot = True)
  plt.title(title, fontsize=15)
  return chart

# %%
correlation_plot_2(df_spearman.corr());

# %%
#Creo dos grupos para probar la hipotesis de que las casas de mejor calidad son más costosas
df_HighQual = df[df['OverallQual'] > 5 ].copy()
df_LowQual = df[df['OverallQual'] <= 5 ].copy()

# %%
df_HighQual.shape
# Out:
# (922, 69)

# %%
df_LowQual.shape
# Out:
# (538, 69)

# %%
df_HighQ = df_HighQual[['SalePrice']].copy()
df_LowQ = df_LowQual[['SalePrice']].copy()

# %%
#El P value es microscopico, la hipotesis de que las casas de mejor calidad son más caras se confirma
ttest_ind(df_HighQ.SalePrice, df_LowQ.SalePrice)
# Out:
# Ttest_indResult(statistic=23.978180675989137, pvalue=2.2277449370853986e-107)

# %%
df.YearBuilt.hist();

# %%
#Igual voy a comprobar si las casas construidas luego de 1990 son más costosas
df_Older = df[df['YearBuilt'] < 1990 ].copy()
df_Newer = df[df['YearBuilt'] >= 1990 ].copy()

# %%
df_O = df_Older[['SalePrice']].copy()
df_N = df_Newer[['SalePrice']].copy()

# %%
print(df_O.SalePrice.mean())
print(df_N.SalePrice.mean())
# Out:
# 146148.14411441144
# 238287.26497277676

# %%
#Las casas más nuevas son más caras, el P value lo confirma
ttest_ind(df_O.SalePrice, df_N.SalePrice)
# Out:
# Ttest_indResult(statistic=-25.97099401941119, pvalue=1.547160239369537e-122)

# %%
#Ahora probando casas remodeladas antes y despues de 1990
df_RemodOld = df[df['YearRemodAdd'] < 1990 ].copy()
df_RemodNew = df[df['YearRemodAdd'] >= 1990 ].copy()

# %%
df_RO = df_RemodOld[['SalePrice']].copy()
df_RN = df_RemodNew[['SalePrice']].copy()

# %%
#También se confirma que las casas remodeladas despues de 1990 son más costosas
ttest_ind(df_RO.SalePrice, df_RN.SalePrice)
# Out:
# Ttest_indResult(statistic=-20.166546730240043, pvalue=5.710293853357072e-80)

# %%
#Regresión lineal entre esos 3 factores y el precio de ventas
X = sm.add_constant(df[['OverallQual', 'YearBuilt', 'YearRemodAdd']])
Y = df.SalePrice

model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 

print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.636
# Model:                            OLS   Adj. R-squared:                  0.635
# Method:                 Least Squares   F-statistic:                     848.3
# Date:                Sun, 11 Jul 2021   Prob (F-statistic):          6.18e-319
# Time:                        14:22:22   Log-Likelihood:                -17806.
# No. Observations:                1460   AIC:                         3.562e+04
# Df Residuals:                    1456   BIC:                         3.564e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         -1.01e+06   1.47e+05     -6.853      0.000    -1.3e+06   -7.21e+05
# OverallQual   4.068e+04   1168.941     34.804      0.000    3.84e+04     4.3e+04
# YearBuilt      195.2273     55.480      3.519      0.000      86.397     304.057
# YearRemodAdd   281.1599     79.736      3.526      0.000     124.749     437.570
# ==============================================================================
# Omnibus:                      668.301   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7683.485
# Skew:                           1.824   Prob(JB):                         0.00
# Kurtosis:                      13.630   Cond. No.                     3.28e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.28e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#Elimino un par de columnas más para hacer un PCA
null_cols = newdf.isnull().sum()
null_cols[null_cols > 0]
# Out:
# MasVnrArea      8
# GarageYrBlt    81
# dtype: int64

# %%
#Elimino un par de columnas más para hacer un PCA
drop_cols = list(null_cols[null_cols > 1].index)
newdf = newdf.drop(drop_cols, axis=1)

# %%
newdf.shape
# Out:
# (1460, 29)

# %%
#Aplico la estandarización de los datos
x = StandardScaler().fit_transform(newdf)
x_norm = pd.DataFrame(x)
x_norm.head(1)
# Out:
#          0         1         2         3       4         5         6   \
# 0  0.073375  0.212877 -0.207142  0.651479 -0.5172  1.050994  0.878668
#
#          7         8         9   ...       19        20        21     22  \
# 0  0.575425 -0.288653 -0.944591  ...  0.91221 -0.951226  0.311725  0.351
#
#          23        24        25        26        27        28
# 0 -0.752176  0.216503 -0.359325 -1.599111  0.138777  0.347273
#
# [1 rows x 29 columns]

# %%
#Procedo con el PCA
pca = PCA()
principal_components = pca.fit_transform(x)

# %%
pca.explained_variance_ratio_
# Out:
# array([2.48359891e-01, 1.08023433e-01, 7.11586645e-02, 7.00708894e-02,
#        4.88938550e-02, 4.01576364e-02, 3.70547126e-02, 3.62475998e-02,
#        3.43678319e-02, 3.31016029e-02, 3.20998607e-02, 2.89351686e-02,
#        2.78036152e-02, 2.55881856e-02, 2.53036830e-02, 2.42661800e-02,
#        2.01746677e-02, 1.69098404e-02, 1.44277933e-02, 1.19794285e-02,
#        1.02909872e-02, 9.26862463e-03, 6.85108073e-03, 5.55092137e-03,
#        5.02435451e-03, 4.56654138e-03, 3.40223428e-03, 1.20715773e-04,
#        6.28372387e-33])

# %%
#Comprobación
sum(pca.explained_variance_ratio_)
# Out:
# 0.9999999999999998

# %%
#Los primeros 12 hacen el pareto
sum(pca.explained_variance_ratio_[:13])
# Out:
# 0.8162747616383554

# %%
#Reentreno el modelo con 12 componentes
pca = PCA(n_components = 12)
pca.fit(x)
# Out:
# PCA(n_components=12)

# %%
#Creando el DF
df_pca_comp = pd.DataFrame(
    data = pca.components_,
    columns = x_norm.columns.values,
    index = ["Componente 1", "Componente 2",'Componente 3', 'Componente 4', 
    'Componente 5', 'Componente 6', 'Componente 7', 'Componente 8', 
    'Componente 9', 'Componente 10', 'Componente 11', 'Componente 12']
    )
df_pca_comp
# Out:
#                      0         1         2         3         4         5   \
# Componente 1  -0.017990  0.098817  0.111153  0.303674 -0.069803  0.220257
# Componente 2   0.189404 -0.003774 -0.068859 -0.019444  0.040514 -0.156998
# Componente 3  -0.265522  0.219104  0.273601 -0.150943  0.091319 -0.392404
# Componente 4   0.218566 -0.148994  0.132240 -0.061202  0.129554 -0.095369
# Componente 5   0.372044 -0.023451 -0.094721 -0.112364 -0.451111  0.124648
# Componente 6   0.020257 -0.040268  0.034116 -0.009623 -0.170253 -0.004126
# Componente 7   0.051035 -0.409986  0.268100 -0.080302 -0.109032  0.100280
# Componente 8   0.248310 -0.212831 -0.132898  0.107955  0.589587 -0.139494
# Componente 9   0.308509 -0.414355 -0.024313  0.137197 -0.162169 -0.095065
# Componente 10  0.089014  0.189653 -0.194902  0.052261  0.061997  0.007935
# Componente 11  0.040854 -0.066946 -0.118459  0.029216 -0.116554  0.029433
# Componente 12 -0.081661 -0.005248 -0.131513  0.052048 -0.242680  0.005768
#
#                      6         7         8         9   ...        19  \
# Componente 1   0.203274  0.139218 -0.008853  0.115901  ...  0.248638
# Componente 2  -0.060703 -0.326623 -0.093044  0.125958  ...  0.302778
# Componente 3  -0.319926  0.087020  0.154127  0.059579  ...  0.204667
# Componente 4  -0.073549  0.367418  0.145208 -0.569831  ...  0.064706
# Componente 5  -0.113818  0.139483 -0.103394 -0.052553  ...  0.077277
# Componente 6  -0.163781  0.067776 -0.068522 -0.053128  ... -0.048401
# Componente 7  -0.044129 -0.252550  0.490312  0.115136  ...  0.001818
# Componente 8   0.323101  0.057650 -0.165560  0.054196  ...  0.012720
# Componente 9  -0.121122 -0.071004  0.007272  0.151676  ... -0.101424
# Componente 10  0.139108 -0.186939  0.742642 -0.104359  ... -0.020959
# Componente 11  0.006876  0.063545  0.064433  0.099341  ... -0.000093
# Componente 12 -0.113878 -0.006538 -0.063742  0.024238  ... -0.032344
#
#                      20        21        22        23        24        25  \
# Componente 1   0.190414  0.279103  0.273299  0.133886  0.149546 -0.064962
# Componente 2  -0.023294 -0.065187 -0.105355 -0.078506  0.034201  0.095813
# Componente 3   0.132533 -0.139097 -0.074074 -0.030810 -0.049692  0.261808
# Componente 4   0.155318 -0.077226 -0.062655  0.144969  0.017299  0.024754
# Componente 5  -0.189525  0.041677  0.026979 -0.086388 -0.129659 -0.101727
# Componente 6   0.104030  0.000694 -0.003791 -0.086081  0.184606 -0.025378
# Componente 7   0.137489 -0.108936 -0.158692  0.421577 -0.048173 -0.350413
# Componente 8  -0.033778 -0.137224 -0.135079  0.127843  0.071643  0.041921
# Componente 9   0.326488  0.057742  0.035422 -0.051197 -0.061994  0.581312
# Componente 10 -0.237647  0.158798  0.174097 -0.185092  0.151832  0.275863
# Componente 11  0.058578 -0.354200 -0.330299 -0.350890  0.676645 -0.149067
# Componente 12  0.190373 -0.020397 -0.035765 -0.003541 -0.063405  0.142578
#
#                      26        27        28
# Componente 1   0.024415 -0.014695  0.332774
# Componente 2   0.028656 -0.034438 -0.047886
# Componente 3   0.007281 -0.005250 -0.020244
# Componente 4  -0.043477  0.054905  0.038211
# Componente 5  -0.023375  0.028687 -0.102212
# Componente 6   0.618620 -0.694771 -0.017832
# Componente 7   0.083814  0.024381 -0.047395
# Componente 8   0.305087  0.035424  0.054745
# Componente 9  -0.235986 -0.093066  0.050158
# Componente 10  0.149966 -0.006717 -0.006207
# Componente 11 -0.157081  0.120345 -0.022430
# Componente 12  0.620475  0.656036  0.002868
#
# [12 rows x 29 columns]

# %%
#Coloco los nombres de las columnas para mejor análisis
data_pca_comp = pd.DataFrame (data = pca.components_, 
                              columns = newdf.columns.values, 
                              index = ['Componente 1', 'Componente 2', 'Componente 3', 
                                       'Componente 4', 'Componente 5', 'Componente 6', 
                                       'Componente 7', 'Componente 8', 'Componente 9', 
                                       'Componente 10', 'Componente 11', 'Componente 12'])
data_pca_comp
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# Componente 1    -0.017990     0.098817  0.111153     0.303674    -0.069803
# Componente 2     0.189404    -0.003774 -0.068859    -0.019444     0.040514
# Componente 3    -0.265522     0.219104  0.273601    -0.150943     0.091319
# Componente 4     0.218566    -0.148994  0.132240    -0.061202     0.129554
# Componente 5     0.372044    -0.023451 -0.094721    -0.112364    -0.451111
# Componente 6     0.020257    -0.040268  0.034116    -0.009623    -0.170253
# Componente 7     0.051035    -0.409986  0.268100    -0.080302    -0.109032
# Componente 8     0.248310    -0.212831 -0.132898     0.107955     0.589587
# Componente 9     0.308509    -0.414355 -0.024313     0.137197    -0.162169
# Componente 10    0.089014     0.189653 -0.194902     0.052261     0.061997
# Componente 11    0.040854    -0.066946 -0.118459     0.029216    -0.116554
# Componente 12   -0.081661    -0.005248 -0.131513     0.052048    -0.242680
#
#                YearBuilt  YearRemodAdd  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# Componente 1    0.220257      0.203274    0.139218   -0.008853   0.115901
# Componente 2   -0.156998     -0.060703   -0.326623   -0.093044   0.125958
# Componente 3   -0.392404     -0.319926    0.087020    0.154127   0.059579
# Componente 4   -0.095369     -0.073549    0.367418    0.145208  -0.569831
# Componente 5    0.124648     -0.113818    0.139483   -0.103394  -0.052553
# Componente 6   -0.004126     -0.163781    0.067776   -0.068522  -0.053128
# Componente 7    0.100280     -0.044129   -0.252550    0.490312   0.115136
# Componente 8   -0.139494      0.323101    0.057650   -0.165560   0.054196
# Componente 9   -0.095065     -0.121122   -0.071004    0.007272   0.151676
# Componente 10   0.007935      0.139108   -0.186939    0.742642  -0.104359
# Componente 11   0.029433      0.006876    0.063545    0.064433   0.099341
# Componente 12   0.005768     -0.113878   -0.006538   -0.063742   0.024238
#
#                ...  TotRmsAbvGrd  Fireplaces  GarageCars  GarageArea  \
# Componente 1   ...      0.248638    0.190414    0.279103    0.273299
# Componente 2   ...      0.302778   -0.023294   -0.065187   -0.105355
# Componente 3   ...      0.204667    0.132533   -0.139097   -0.074074
# Componente 4   ...      0.064706    0.155318   -0.077226   -0.062655
# Componente 5   ...      0.077277   -0.189525    0.041677    0.026979
# Componente 6   ...     -0.048401    0.104030    0.000694   -0.003791
# Componente 7   ...      0.001818    0.137489   -0.108936   -0.158692
# Componente 8   ...      0.012720   -0.033778   -0.137224   -0.135079
# Componente 9   ...     -0.101424    0.326488    0.057742    0.035422
# Componente 10  ...     -0.020959   -0.237647    0.158798    0.174097
# Componente 11  ...     -0.000093    0.058578   -0.354200   -0.330299
# Componente 12  ...     -0.032344    0.190373   -0.020397   -0.035765
#
#                WoodDeckSF  OpenPorchSF  EnclosedPorch    MoSold    YrSold  \
# Componente 1     0.133886     0.149546      -0.064962  0.024415 -0.014695
# Componente 2    -0.078506     0.034201       0.095813  0.028656 -0.034438
# Componente 3    -0.030810    -0.049692       0.261808  0.007281 -0.005250
# Componente 4     0.144969     0.017299       0.024754 -0.043477  0.054905
# Componente 5    -0.086388    -0.129659      -0.101727 -0.023375  0.028687
# Componente 6    -0.086081     0.184606      -0.025378  0.618620 -0.694771
# Componente 7     0.421577    -0.048173      -0.350413  0.083814  0.024381
# Componente 8     0.127843     0.071643       0.041921  0.305087  0.035424
# Componente 9    -0.051197    -0.061994       0.581312 -0.235986 -0.093066
# Componente 10   -0.185092     0.151832       0.275863  0.149966 -0.006717
# Componente 11   -0.350890     0.676645      -0.149067 -0.157081  0.120345
# Componente 12   -0.003541    -0.063405       0.142578  0.620475  0.656036
#
#                SalePrice
# Componente 1    0.332774
# Componente 2   -0.047886
# Componente 3   -0.020244
# Componente 4    0.038211
# Componente 5   -0.102212
# Componente 6   -0.017832
# Componente 7   -0.047395
# Componente 8    0.054745
# Componente 9    0.050158
# Componente 10  -0.006207
# Componente 11  -0.022430
# Componente 12   0.002868
#
# [12 rows x 29 columns]

# %%
"""12 componentes, con sus respectivos coeficientes explican el valor de las casas, 
    que va a estar dado por multiplicar el coeficiente de cada componente
    por el valor que tiene cada casa en ese componente"""

pca.explained_variance_ratio_[:13]
# Out:
# array([0.24835989, 0.10802343, 0.07115866, 0.07007089, 0.04889385,
#        0.04015763, 0.03705469, 0.0362476 , 0.03436783, 0.03310157,
#        0.03209984, 0.02893513])

# %%
#FIN
